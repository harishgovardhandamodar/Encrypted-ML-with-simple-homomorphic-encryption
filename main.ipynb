# %%
# architecture
## load reasonable dataset -> encrypt the dataset such that it is homomorphically parsable
## build homomorphic encryption enabled model -> obtain accuracy on performing inference on HE-based data
## build benchmark model with original data -> obtain accuracy based on non-HE data

# dataset: credit scoring benchmark dataset (credit default, client characteristics dataset)
# https://archive.ics.uci.edu/ml/machine-learning-databases/00350/

import pandas as pd
from utils import dataload
from model import vanillaModel, homomorphicEncryptionModel

cci_data = pd.read_csv("uci_cci.csv")

input_cols = list(cci_data.columns)[:-1]
output_cols = list(cci_data.columns)[-1]

x_data, y_data, x_data_shortened, y_data_shortened, X_enc, y_enc, H_enc = dataload(cci_data, input_cols, output_cols)

# https://www.cs.cmu.edu/~rjhall/JOS_revised_May_31a.pdf
# source for use of orthogonal matrices and invertible matrices transformation for homomorophic encryption

# Test case 1: Vanilla model (benchmark credit rating/scoring model for default prediction)
vanillaModel(x_data, y_data)
# Test case 2: Homomorphic encryption model running on encrypted data
homomorphicEncryptionModel(X_enc, y_enc, x_data, H_enc)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmpgw62eexn
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmpgw62eexn', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /Users/nirhanjaniharish/miniforge3/envs/mlp/lib/python3.8/site-packages/tensorflow/python/training/training_util.py:396: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /Users/nirhanjaniharish/miniforge3/envs/mlp/lib/python3.8/site-packages/keras/optimizer_v2/adagrad.py:83: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmpgw62eexn/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 5558.501, step = 0
# INFO:tensorflow:global_step/sec: 89.6325
# INFO:tensorflow:loss = 1780.0995, step = 100 (1.116 sec)
# INFO:tensorflow:global_step/sec: 103.523
# INFO:tensorflow:loss = 1490.363, step = 200 (0.966 sec)
# INFO:tensorflow:global_step/sec: 103.658
# INFO:tensorflow:loss = 1020.87244, step = 300 (0.965 sec)
# INFO:tensorflow:global_step/sec: 101.135
# INFO:tensorflow:loss = 779.82446, step = 400 (0.989 sec)
# INFO:tensorflow:global_step/sec: 93.3798
# INFO:tensorflow:loss = 780.0701, step = 500 (1.071 sec)
# INFO:tensorflow:global_step/sec: 102.27
# INFO:tensorflow:loss = 401.508, step = 600 (0.978 sec)
# INFO:tensorflow:global_step/sec: 104.384
# INFO:tensorflow:loss = 758.9038, step = 700 (0.958 sec)
# INFO:tensorflow:global_step/sec: 104.659
# INFO:tensorflow:loss = 504.36108, step = 800 (0.955 sec)
# INFO:tensorflow:global_step/sec: 104.887
# INFO:tensorflow:loss = 356.12866, step = 900 (0.953 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1000...
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmpgw62eexn/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1000...
# INFO:tensorflow:Loss for final step: 239.8598.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2022-03-21T17:35:34
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmpgw62eexn/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Inference Time : 0.85651s
# INFO:tensorflow:Finished evaluation at 2022-03-21-17:35:35
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.671875, accuracy_baseline = 0.796875, auc = 0.5147059, auc_precision_recall = 0.2126238, average_loss = 409.3985, global_step = 1000, label/mean = 0.203125, loss = 409.3985, precision = 0.22413793, prediction/mean = 0.22656262, recall = 0.25
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmpgw62eexn/model.ckpt-1000
#
# Test set accuracy: 0.672
#
# WARNING:tensorflow:From /Users/nirhanjaniharish/miniforge3/envs/mlp/lib/python3.8/site-packages/tensorflow/python/util/lazy_loader.py:59: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
#
# WARNING:tensorflow:From /Users/nirhanjaniharish/Data/codebase/Encrypted-machine-learning-with-simple-homomorphic-encryption-master/Encrypted-machine-learning-with-simple-homomorphic-encryption-master/model.py:67: The name tf.estimator.inputs.pandas_input_fn is deprecated. Please use tf.compat.v1.estimator.inputs.pandas_input_fn instead.
#
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmp_h061eso
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmp_h061eso', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /Users/nirhanjaniharish/miniforge3/envs/mlp/lib/python3.8/site-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:60: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /Users/nirhanjaniharish/miniforge3/envs/mlp/lib/python3.8/site-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:491: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /Users/nirhanjaniharish/miniforge3/envs/mlp/lib/python3.8/site-packages/tensorflow/python/training/monitored_session.py:914: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmp_h061eso/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 4281516000.0, step = 0
# INFO:tensorflow:global_step/sec: 111.827
# INFO:tensorflow:loss = 3207456.0, step = 100 (0.895 sec)
# INFO:tensorflow:global_step/sec: 126.856
# INFO:tensorflow:loss = 23485.6, step = 200 (0.788 sec)
# INFO:tensorflow:global_step/sec: 127.848
# INFO:tensorflow:loss = 223858.67, step = 300 (0.782 sec)
# INFO:tensorflow:global_step/sec: 124.427
# INFO:tensorflow:loss = 878.8297, step = 400 (0.804 sec)
# INFO:tensorflow:global_step/sec: 122.958
# INFO:tensorflow:loss = 367737.2, step = 500 (0.813 sec)
# INFO:tensorflow:global_step/sec: 126.865
# INFO:tensorflow:loss = 312523.4, step = 600 (0.788 sec)
# INFO:tensorflow:global_step/sec: 126.641
# INFO:tensorflow:loss = 111.3017, step = 700 (0.790 sec)
# INFO:tensorflow:global_step/sec: 126.743
# INFO:tensorflow:loss = 11542.292, step = 800 (0.789 sec)
# INFO:tensorflow:global_step/sec: 126.066
# INFO:tensorflow:loss = 0.64098865, step = 900 (0.793 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1000...
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmp_h061eso/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1000...
# INFO:tensorflow:Loss for final step: 0.1806521.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2022-03-21T17:35:50
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmp_h061eso/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.72431s
# INFO:tensorflow:Finished evaluation at 2022-03-21-17:35:51
# INFO:tensorflow:Saving dict for global step 1000: average_loss = 1468.2926, global_step = 1000, label/mean = -0.046832174, loss = 1248.0947, prediction/mean = -5.704468
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmp_h061eso/model.ckpt-1000
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmp_h061eso/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# HE accuracy:  0.9607843137254902
