# %%
# architecture
## load reasonable dataset -> encrypt the dataset such that it is homomorphically parsable
## build homomorphic encryption enabled model -> obtain accuracy on performing inference on HE-based data
## build benchmark model with original data -> obtain accuracy based on non-HE data

# dataset: credit scoring benchmark dataset (credit default, client characteristics dataset)
# https://archive.ics.uci.edu/ml/machine-learning-databases/00350/

import pandas as pd
from utils import dataload
from model import vanillaModel, homomorphicEncryptionModel

cci_data = pd.read_csv("uci_cci.csv")

input_cols = list(cci_data.columns)[:-1]
output_cols = list(cci_data.columns)[-1]

x_data, y_data, x_data_shortened, y_data_shortened, X_enc, y_enc, H_enc = dataload(cci_data, input_cols, output_cols)

# https://www.cs.cmu.edu/~rjhall/JOS_revised_May_31a.pdf
# source for use of orthogonal matrices and invertible matrices transformation for homomorophic encryption

# Test case 1: Vanilla model (benchmark credit rating/scoring model for default prediction)
vanillaModel(x_data, y_data)
# Test case 2: Homomorphic encryption model running on encrypted data
homomorphicEncryptionModel(X_enc, y_enc, x_data, H_enc)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmpv2mzxory
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmpv2mzxory', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /Users/nirhanjaniharish/miniforge3/envs/mlp/lib/python3.8/site-packages/tensorflow/python/training/training_util.py:396: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /Users/nirhanjaniharish/miniforge3/envs/mlp/lib/python3.8/site-packages/keras/optimizer_v2/adagrad.py:83: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmpv2mzxory/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 19171.195, step = 0
# INFO:tensorflow:global_step/sec: 83.8244
# INFO:tensorflow:loss = 8018.088, step = 100 (1.195 sec)
# INFO:tensorflow:global_step/sec: 94.8564
# INFO:tensorflow:loss = 4770.592, step = 200 (1.053 sec)
# INFO:tensorflow:global_step/sec: 105.612
# INFO:tensorflow:loss = 3174.2139, step = 300 (0.947 sec)
# INFO:tensorflow:global_step/sec: 105.83
# INFO:tensorflow:loss = 2358.6938, step = 400 (0.945 sec)
# INFO:tensorflow:global_step/sec: 106.129
# INFO:tensorflow:loss = 2848.1963, step = 500 (0.942 sec)
# INFO:tensorflow:global_step/sec: 106.088
# INFO:tensorflow:loss = 2580.7083, step = 600 (0.943 sec)
# INFO:tensorflow:global_step/sec: 105.272
# INFO:tensorflow:loss = 1731.9272, step = 700 (0.950 sec)
# INFO:tensorflow:global_step/sec: 104.746
# INFO:tensorflow:loss = 2237.306, step = 800 (0.955 sec)
# INFO:tensorflow:global_step/sec: 105.629
# INFO:tensorflow:loss = 1715.4531, step = 900 (0.947 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1000...
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmpv2mzxory/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1000...
# INFO:tensorflow:Loss for final step: 2102.0469.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2022-03-21T19:08:11
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmpv2mzxory/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Inference Time : 0.66633s
# INFO:tensorflow:Finished evaluation at 2022-03-21-19:08:11
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.67578125, accuracy_baseline = 0.79296875, auc = 0.52370113, auc_precision_recall = 0.22291327, average_loss = 2079.979, global_step = 1000, label/mean = 0.20703125, loss = 2079.979, precision = 0.2413793, prediction/mean = 0.226561, recall = 0.26415095
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmpv2mzxory/model.ckpt-1000
#
# Test set accuracy: 0.676
#
# WARNING:tensorflow:From /Users/nirhanjaniharish/miniforge3/envs/mlp/lib/python3.8/site-packages/tensorflow/python/util/lazy_loader.py:59: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
#
# WARNING:tensorflow:From /Users/nirhanjaniharish/Data/codebase/Encrypted-ML-with-simple-homomorphic-encryption/Encrypted-ML-with-simple-homomorphic-encryption/Encrypted-ML-with-simple-homomorphic-encryption/model.py:67: The name tf.estimator.inputs.pandas_input_fn is deprecated. Please use tf.compat.v1.estimator.inputs.pandas_input_fn instead.
#
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmpoyynsscc
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmpoyynsscc', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /Users/nirhanjaniharish/miniforge3/envs/mlp/lib/python3.8/site-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:60: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /Users/nirhanjaniharish/miniforge3/envs/mlp/lib/python3.8/site-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:491: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /Users/nirhanjaniharish/miniforge3/envs/mlp/lib/python3.8/site-packages/tensorflow/python/training/monitored_session.py:914: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmpoyynsscc/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 11909935000.0, step = 0
# INFO:tensorflow:global_step/sec: 111.835
# INFO:tensorflow:loss = 372284.53, step = 100 (0.895 sec)
# INFO:tensorflow:global_step/sec: 128.061
# INFO:tensorflow:loss = 20492.49, step = 200 (0.781 sec)
# INFO:tensorflow:global_step/sec: 127.861
# INFO:tensorflow:loss = 399.0921, step = 300 (0.782 sec)
# INFO:tensorflow:global_step/sec: 127.293
# INFO:tensorflow:loss = 0.30818385, step = 400 (0.786 sec)
# INFO:tensorflow:global_step/sec: 127.163
# INFO:tensorflow:loss = 0.71652144, step = 500 (0.786 sec)
# INFO:tensorflow:global_step/sec: 126.624
# INFO:tensorflow:loss = 0.33001816, step = 600 (0.790 sec)
# INFO:tensorflow:global_step/sec: 127.591
# INFO:tensorflow:loss = 0.47360572, step = 700 (0.784 sec)
# INFO:tensorflow:global_step/sec: 127.626
# INFO:tensorflow:loss = 0.21531172, step = 800 (0.784 sec)
# INFO:tensorflow:global_step/sec: 126.12
# INFO:tensorflow:loss = 0.09651654, step = 900 (0.793 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1000...
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmpoyynsscc/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1000...
# INFO:tensorflow:Loss for final step: 0.70261496.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2022-03-21T19:08:25
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmpoyynsscc/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.28805s
# INFO:tensorflow:Finished evaluation at 2022-03-21-19:08:25
# INFO:tensorflow:Saving dict for global step 1000: average_loss = 0.3054588, global_step = 1000, label/mean = -0.101105645, loss = 0.25976977, prediction/mean = 0.11194971
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmpoyynsscc/model.ckpt-1000
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/g8/ym0fcvyn37sbxprqb1jb2jvr0000gn/T/tmpoyynsscc/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# HE accuracy:  1.0
